# %%
import pandas as pd

# %%
pd.options.display.max_columns = None
pd.options.display.max_rows = None

# %%
pop = pd.read_sas("s3://alpha-omppg/ISP Population/Final Datasets/isp_pop_2023q3.sas7bdat", encoding='latin1')
pop.head()
# Out:
#   NOMIS_ID   Surname initial        DOS   TARIFF_EXPIRY_DATE SentenceStatus  \
# 0  A0001AC   CASTREE       R 2007-11-12  2036-11-05 00:00:00       (6) Life
# 1  A0001EV  PRZYBYLA       L        NaT                  NaT       (6) Life
# 2  A0003AC      INGS       A 2008-10-21  2038-02-03 00:00:00       (6) Life
# 3  A0004AC   JOHNSON       J 2005-09-19  2030-09-19 00:00:00       (6) Life
# 4  A0004AL      FOYE       L 2011-11-15  2046-11-15 00:00:00       (6) Life
#
#   custody_type_description status_description determinate_flag dateOfBirth  \
# 0          Mandatory (MLP)     In Custody [*]            False  1953-10-18
# 1                      NaN                NaN              NaN  1988-07-22
# 2          Mandatory (MLP)     In Custody [*]            False  1972-05-09
# 3          Mandatory (MLP)     In Custody [*]            False  1973-08-21
# 4          Mandatory (MLP)     In Custody [*]            False  1985-04-30
#
#                                     Offence index_offence_description  \
# 0  Murder - victim one year of age or older                    Murder
# 1  Murder - victim one year of age or older                       NaN
# 2  Murder - victim one year of age or older                    Murder
# 3  Murder - victim one year of age or older                    Murder
# 4  Murder - victim one year of age or older                    Murder
#
#         PrisonName      ppud_prison   AGE      Ageband      CRO_NO CSRA_LEVEL  \
# 0  WAKEFIELD (HMP)    HMP Wakefield  69.0  60 and over  104113/76L   Standard
# 1   DOVEGATE (HMP)              NaN  34.0      30 - 39  116421/13D   Standard
# 2  WAKEFIELD (HMP)    HMP Wakefield  51.0      50 - 59  063515/89T   Standard
# 3    OAKWOOD (HMP)      HMP Oakwood  49.0      40 - 49  259397/00C   Standard
# 4  FRANKLAND (HMP)  HMP Full Sutton  38.0      30 - 39  214269/97H       High
#
#   DateofRelease DRUG_OFFENCES PrisonCode  \
# 0           NaT             N        WDI
# 1           NaT             N        DGI
# 2           NaT             N        WDI
# 3           NaT             N        OWI
# 4           NaT             N        FKI
#
#                                EthnicGroup ExtractDate F2052Start  \
# 0  White: Eng./Welsh/Scot./N.Irish/British  2023-06-30        NaT
# 1              White: Any other background  2023-06-30 2022-04-05
# 2  White: Eng./Welsh/Scot./N.Irish/British  2023-06-30 2023-06-28
# 3           Black/Black British: Caribbean  2023-06-30        NaT
# 4  White: Eng./Welsh/Scot./N.Irish/British  2023-06-30 2013-12-26
#
#   F2052_STATUS FirstConvicted FirstMovement FirstSentenced Forename  IEP  \
# 0          NaN     2006-11-07    2006-11-07     2007-11-12   RONALD  ENH
# 1     INACTIVE     2023-01-19    2022-03-24     2023-01-19   LUKASZ  STD
# 2       ACTIVE     2008-02-04    2008-02-04     2008-10-21     ALAN  ENH
# 3          NaN     2004-12-08    2004-06-30     2005-09-19   JARVIS  ENH
# 4       ACTIVE     2006-03-23    2006-09-19     2006-03-23      LEE  ENH
#
#   IMPRISONMENT_STATUS_CATEGORY INDEFINITE_SENTENCE LAST_MOVEMENT_DATE  \
# 0          Indefinite Sentence                   Y         2022-10-12
# 1                    Sentenced                   N         2023-01-19
# 2          Indefinite Sentence                   Y         2020-06-04
# 3          Indefinite Sentence                   Y         2021-05-04
# 4          Indefinite Sentence                   Y         2021-02-26
#
#   LAST_MOVEMENT_DIRECTION    LAST_MOVEMENT_FROM  \
# 0                      IN                   NaN
# 1                      IN  Stafford Crown Court
# 2                      IN       FRANKLAND (HMP)
# 3                      IN         GARTREE (HMP)
# 4                      IN                   NaN
#
#                     LAST_MOVEMENT_REASON LAST_MOVEMENT_TO LAST_MOVEMENT_TYPE  \
# 0  Medical/Dental Outpatient Appointment  WAKEFIELD (HMP)  Temporary Absence
# 1                       Court Appearance   DOVEGATE (HMP)              Court
# 2   Transfer In from Other Establishment  WAKEFIELD (HMP)          Admission
# 3   Transfer In from Other Establishment    OAKWOOD (HMP)          Admission
# 4  Medical/Dental Outpatient Appointment  FRANKLAND (HMP)  Temporary Absence
#
#      CellLocation MAIN_OFFENCE_STATUTE  \
# 0     WDI-C-1-002           Common Law
# 1   DGI-HB1-D-051           Common Law
# 2     WDI-D-2-014           Common Law
# 3    OWI-C-A4-014           Common Law
# 4  FKI-PIPE-1-006           Common Law
#
#                              MaritalStatus MATERNITY_ONGOING_OR_INACTIVE  \
# 0                    Divorced or dissolved                           NaN
# 1  Single-not married/in civil partnership                           NaN
# 2          Married or in civil partnership                           NaN
# 3                        Prefer not to say                           NaN
# 4  Single-not married/in civil partnership                           NaN
#
#   MaternityStatus NationalityName Gender    PNCID_NO  \
# 0             NaN         British      M  76/104113X
# 1             NaN          Polish      M  13/189401T
# 2             NaN         British      M   89/63515R
# 3             NaN        Jamaican      M  00/177816C
# 4             NaN         British      M  97/478386K
#
#                        Religion SEC_CAT_ASSESSMENT_DATE SecurityCategory  \
# 0  Church of England (Anglican)              2022-11-01            Cat B
# 1                     Christian              2023-01-25            Cat B
# 2  Church of England (Anglican)              2023-05-15            Cat A
# 3                   Rastafarian              2023-05-23            Cat C
# 4                        Muslim              2022-08-25            Cat A
#
#   SEX_OFFENDER_REGISTER SEXUAL VIOLENT PrisonGender          PrisonPGDRegion  \
# 0                     N      N       Y            M  Long Term High Security
# 1                     N      N       Y            M               Contracted
# 2                     N      N       Y            M  Long Term High Security
# 3                     N      N       Y            M               Contracted
# 4                     N      N       Y            M  Long Term High Security
#
#    FNPStatus   MainFunction                  PrisonProbationRegion  \
# 0  B British  High Security  Region C NPS Yorkshire and Humberside
# 1      A FNO  Cat B Trainer             Region E NPS West Midlands
# 2  B British  High Security  Region C NPS Yorkshire and Humberside
# 3      A FNO  Cat C Trainer             Region E NPS West Midlands
# 4  B British  High Security                Region A NPS North East
#
#   PrisonEDRegion SecCatSummary                    OffenceGroup  \
# 0          LTHSE         Cat B  01 Violence against the person
# 1  PrivateSector         Cat B  01 Violence against the person
# 2          LTHSE         Cat A  01 Violence against the person
# 3  PrivateSector         Cat C  01 Violence against the person
# 4          LTHSE         Cat A  01 Violence against the person
#
#   ImprisonmentStatusShort offgrp4 offgrp2 Progression_Regime Open_Type  \
# 0                    LIFE    VATP  non-Se                  N    Closed
# 1                  SENT03    VATP  non-Se                  N    Closed
# 2                     MLP    VATP  non-Se                  N    Closed
# 3                    LIFE    VATP  non-Se                  N    Closed
# 4                     MLP    VATP  non-Se                  N    Closed
#
#   Conditions EXCLUDED_FROM_OPEN WHOLE_LIFE LATEST_RELEASE_DATE PRISON_NUMBER  \
# 0     Closed                NaN        NaN                 NaT        TW6550
# 1     Closed                NaN        NaN                 NaT           NaN
# 2     Closed                NaN        NaN                 NaT        WD5303
# 3     Closed                NaN        NaN                 NaT        LJ8468
# 4     Closed                NaN        NaN                 NaT        MA7907
#
#   PROBATION_SERVICE_DESCRIPTION        Effective_TED Detailed_Offence_Group  \
# 0                   PS - Oldham  2036-11-05 00:00:00               1 Murder
# 1                           NaN                  NaT               1 Murder
# 2                PS - Doncaster  2038-02-03 00:00:00               1 Murder
# 3                           NaN  2030-09-19 00:00:00               1 Murder
# 4                           NaN  2046-11-15 00:00:00               1 Murder
#
#   tariff_past  TARIFF_MONTHS  TARIFF_YEARS  SERVED_MONTHS  SERVED_YEARS  \
# 0           N          347.0          28.0          187.0          15.0
# 1         n/a            NaN           NaN            NaN           NaN
# 2           N          351.0          29.0          176.0          14.0
# 3           N          300.0          25.0          213.0          17.0
# 4           N          420.0          35.0          139.0          11.0
#
#    TARIFFS_SERVED  OVERTARIFF_MONTHS  OVERTARIFF_YEARS  SENTENCED_AGE  \
# 0             0.0                NaN               NaN           54.0
# 1             NaN                NaN               NaN            NaN
# 2             0.0                NaN               NaN           36.0
# 3             0.0                NaN               NaN           32.0
# 4             0.0                NaN               NaN           26.0
#
#   tariff_in_quarter                  tariff first_release_date  \
# 0               NaT    i More than 20 years                NaT
# 1               NaT  k Tariff not available                NaT
# 2               NaT    i More than 20 years                NaT
# 3               NaT    i More than 20 years                NaT
# 4               NaT    i More than 20 years                NaT
#
#   first_release_conditions  years_before_release  months_before_release  \
# 0                      NaN                   NaN                    NaN
# 1                      NaN                   NaN                    NaN
# 2                      NaN                   NaN                    NaN
# 3                      NaN                   NaN                    NaN
# 4                      NaN                   NaN                    NaN
#
#   last_release_date last_release_type last_release_conditions  \
# 0               NaT               NaN                     NaN
# 1               NaT               NaN                     NaN
# 2               NaT               NaN                     NaN
# 3               NaT               NaN                     NaN
# 4               NaT               NaN                     NaN
#
#   last_licence_revoke_date last_rtc_date  last_recallnum  \
# 0                      NaT           NaT             NaN
# 1                      NaT           NaT             NaN
# 2                      NaT           NaT             NaN
# 3                      NaT           NaT             NaN
# 4                      NaT           NaT             NaN
#
#    last_recall_number_of_reasons last_recall_reasons last_recall_area  \
# 0                            NaN                 NaN              NaN
# 1                            NaN                 NaN              NaN
# 2                            NaN                 NaN              NaN
# 3                            NaN                 NaN              NaN
# 4                            NaN                 NaN              NaN
#
#    last_recall_further_charge noms_id_ppud noms_trim noms_start noms_end  \
# 0                         NaN          NaN       NaN        NaN      NaN
# 1                         NaN          NaN       NaN        NaN      NaN
# 2                         NaN          NaN       NaN        NaN      NaN
# 3                         NaN          NaN       NaN        NaN      NaN
# 4                         NaN          NaN       NaN        NaN      NaN
#
#         isp_status      ppud_status  days_recalled  months_recalled  \
# 0  Unreleased Life  Unreleased Life            NaN              NaN
# 1  Unreleased Life  Unreleased Life            NaN              NaN
# 2  Unreleased Life  Unreleased Life            NaN              NaN
# 3  Unreleased Life  Unreleased Life            NaN              NaN
# 4  Unreleased Life  Unreleased Life            NaN              NaN
#
#     custody_stage isp_type last_review_reason last_review_result  \
# 0      Pre-tariff     Life                NaN                NaN
# 1  Unknown tariff     Life                NaN                NaN
# 2      Pre-tariff     Life                NaN                NaN
# 3      Pre-tariff     Life                NaN                NaN
# 4      Pre-tariff     Life                NaN                NaN
#
#   last_review_date last_subsequent_outcome last_subsequent_date  \
# 0              NaT                     NaN                  NaT
# 1              NaT                     NaN                  NaT
# 2              NaT                     NaN                  NaT
# 3              NaT                     NaN                  NaT
# 4              NaT                     NaN                  NaT
#
#    last_reviewnum  max_progress progress_date  open_reviewnum last_open_date  \
# 0             NaN           NaN           NaT             NaN            NaT
# 1             NaN           NaN           NaT             NaN            NaT
# 2             NaN           NaN           NaT             NaN            NaT
# 3             NaN           NaN           NaT             NaN            NaT
# 4             NaN           NaN           NaT             NaN            NaT
#
#   previous_progress
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN

# %%
condition = (pop["isp_status"] == "Unreleased IPP") & (pop["OVERTARIFF_YEARS"].notnull()) & (pop["PrisonGender"] =="F")

pop[condition].groupby("OVERTARIFF_YEARS").size()
# Out:
# OVERTARIFF_YEARS
# 5.0     1
# 7.0     1
# 9.0     1
# 10.0    1
# 11.0    2
# 12.0    1
# 14.0    1
# 15.0    1
# dtype: int64
