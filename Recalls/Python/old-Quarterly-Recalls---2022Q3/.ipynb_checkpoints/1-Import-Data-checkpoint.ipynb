# %% [markdown]
# # 0 Set environment variables

# %% [markdown]
# Get key libraries/modules

# %%
#!pip install pandasql --user

# %%
#! pip3 list

# %%
import ipydatatable
# Out:
# ipydatatable: If no table displayed on initialization, please refresh window.

# %%
# Libraries
import pandas as pd
import numpy as np
import sys # for adding folders to the search path

# SQL code preperation
# from pandasql import sqldf
# pysqldf = lambda q: sqldf(q, globals())

import duckdb
from IPython.display import display, HTML
from ipydatagrid import DataGrid, TextRenderer, VegaExpr
import ipywidgets
# from beakerx import * # table beutifier and other cool stuff 
# import qgrid
import s3fs

# %% [markdown]
# Get max rows and columns - any of the options below works

# %%
# %load_ext sql

# %%
# %config SqlMagic.autopandas = True
# %config SqlMagic.feedback = False
# %config SqlMagic.displaycon = False

# %%
# %sql duckdb:///:memory:

# %%
# print(pd.get_option('display.max_columns'), pd.get_option('display.max_rows'))
print("Defaults: max_col: {}, max_rows: {}, col_width:{}, Number of decimal places: {}".\
      format(pd.options.display.max_columns, 
             pd.options.display.max_rows,
             pd.options.display.max_colwidth,
             pd.options.display.precision
            )
)
# Out:
# Defaults: max_col: 20, max_rows: 60, col_width:50, Number of decimal places: 6

# %% [markdown]
# Remove limits on number of rows and columns to display - any of the options below works

# %%
# pd.set_option('display.max_columns',None)
# pd.set_option('display.max_rows',None)

pd.options.display.max_columns = None
pd.options.display.max_rows = None
pd.options.display.precision = 2
# pd.set_option('max_colwidth',None)

# %% [markdown]
# # 1 Libraries and macro definitions

# %%
# Root directory for Recalls data
rootDir = "s3://alpha-omppg/Recalls"

# Period variables
Quarter = 3 # 1:Jan-Mar, 2:Apr-Jun, 3:Jul-Sep, 4:Oct-Dec
Year = 2022 # Enter the year being run in 4 digit format

# Add macro folder to namespace to import custom modules and their functions
sys.path.append('/home/jovyan/OMPPG/Macro Library')
sys.path.append('/home/jovyan/OMPPG/Recalls/Reference Data/Recalls Lookup') # for recall lookups
#sys.path.append('/home/jovyan/.local/bin')

# %%
# Import own modules
from dateConvert import dateConvert, dateTimeConvert

# %% [markdown]
# # 2 Import and Clean Input Datasets

# %%
extras = pd.read_excel('{}/PPUD/Extra Variables/PPUD_Recalls_{}Q{}_Extra.xls'.format(rootDir,Year,Quarter))#
recalls = pd.read_excel('{}/PPUD/Audited/PPUD_Recalls_{}Q{}.xls'.format(rootDir,Year,Quarter))

# %%
print(recalls.shape,extras.shape)
# Out:
# (6210, 34) (6210, 41)

# %%
display(extras.head(10))
# Out:
#   ALT_FILE_REFERENCE      CRO_PNC CUSTODY_TYPE_DESCRIPTION  \
# 0                NaN    80641/22W              Determinate
# 1                NaN    87718/21G              Determinate
# 2                NaN    98777/22J              Determinate
# 3                NaN          NaN              Determinate
# 4                NaN          NaN              Determinate
# 5                NaN   273235/18L              Determinate
# 6                NaN            0              Determinate
# 7                NaN    000010/00              Determinate
# 8                NaN   002365/88U                Automatic
# 9                NaN   002669/07W              Determinate
#
#   CUSTODY_TYPE_AT_TIME_OF_RECALL_DESCRIPTION                  DOB  \
# 0                                Determinate  29/04/1998 00:00:00
# 1                                Determinate  08/01/1981 00:00:00
# 2                                Determinate  20/09/1972 00:00:00
# 3                                Determinate  07/10/1996 00:00:00
# 4                                Determinate  04/11/1999 00:00:00
# 5                                Determinate  27/05/2002 00:00:00
# 6                                Determinate  02/05/1986 00:00:00
# 7                                Determinate  07/08/1985 00:00:00
# 8                                  Automatic  15/05/1972 00:00:00
# 9                                Determinate  05/08/1986 00:00:00
#
#                    DOS  DETERMINATE_FLAG  \
# 0  02/02/2022 00:00:00              True
# 1  13/01/2022 00:00:00              True
# 2  27/06/2022 00:00:00              True
# 3  04/06/2022 00:00:00              True
# 4  19/07/2021 00:00:00              True
# 5  12/03/2021 00:00:00              True
# 6  13/09/2022 00:00:00              True
# 7  27/09/2021 00:00:00              True
# 8  28/09/2001 00:00:00             False
# 9  28/06/2022 00:00:00              True
#
#                   ETHNICITY_DESCRIPTION               EWS_NUMBER FAMILY_NAME  \
# 0                         White - Other      02RC/1426528E15072       Lleshi
# 1                               Chinese       02RC/0712264E16092       Cheng
# 2                         White - Other  02RC/4458629E19082       Ciubotariu
# 3                         White - Other  02RC/1054208E31082           Yankov
# 4                         White - Other       02RC/0185231D27072      Toskaj
# 5                       White - British  02RC/01268922926082         Dooling
# 6                       White - British       02RC/2064268E16092        Webb
# 7                       White - British       02RC/5006761E26082     Bampton
# 8                       White - British      02RC/44FT958427092     Thompson
# 9  Asian or Asian British - Bangladeshi       02RC/1611511E05072    Tarafdar
#
#   FILE_REFERENCE     FIRST_NAMES GENDER  \
# 0     PPU_394263           Altin      M
# 1     PPU_397348             Wei      M
# 2     PPU_396468         Dumitru      M
# 3     PPU_396772  Krasmir Asenov      M
# 4     PPU_394653          Ardian      M
# 5     PPU_396717          Bailey      M
# 6     PPU_397332           Brett      M
# 7     PPU_396663         Richard      M
# 8         T17226            Mark      M
# 9        AV11133        Mahfuzur      M
#
#                            INDEX_OFFENCE_DESCRIPTION ISSUE_REVOCATION_TARGET  \
# 0                                    POSSESSION DRUG     16/07/2022 16:02:00
# 1                 THREATENING / DISORDERLY BEHAVIOUR     17/09/2022 14:59:00
# 2         DRIVING UNDER THE INFLUENCE OF DRINK/DRUGS     20/08/2022 12:29:00
# 3                                              FRAUD     31/08/2022 14:45:00
# 4                                    PRODUCTION DRUG     28/07/2022 12:59:00
# 5                                    SUPPLYING DRUGS     27/08/2022 16:47:00
# 6                 THREATENING / DISORDERLY BEHAVIOUR     17/09/2022 11:53:00
# 7                               INDECENT PHOTOGRAPHS     26/08/2022 16:07:00
# 8  Attempt to commit murder or a conspiracy to co...     27/09/2022 20:37:00
# 9                                        HARRASSMENT     05/07/2022 17:04:00
#
#            LICENCE_END  LICENCE_REVOKE_DATE        LICENCE_START  \
# 0  10/11/2022 00:00:00  15/07/2022 17:44:00  10/06/2022 00:00:00
# 1  12/01/2023 00:00:00  16/09/2022 16:17:00  22/04/2022 00:00:00
# 2  18/09/2022 00:00:00  19/08/2022 16:52:00  05/08/2022 00:00:00
# 3  18/11/2022 00:00:00  31/08/2022 10:02:00  26/08/2022 00:00:00
# 4  02/06/2023 00:00:00  27/07/2022 15:16:00  14/07/2022 00:00:00
# 5  18/02/2024 00:00:00  26/08/2022 17:48:00  07/02/2022 00:00:00
# 6  00/01/1900 00:00:00  16/09/2022 14:01:00  13/09/2022 00:00:00
# 7  26/11/2022 00:00:00  26/08/2022 11:33:00  27/04/2022 00:00:00
# 8  00/01/1900 00:00:00  27/09/2022 19:49:00  04/01/2021 00:00:00
# 9  11/09/2022 00:00:00  05/07/2022 10:41:00  28/06/2022 00:00:00
#
#   TYPE_OF_LICENCE_DESCRIPTION            MAPPA_LEVEL_DESCRIPTION  \
# 0                    Standard                     Not Applicable
# 1                    Standard  Level 2 - Multi-Agency Management
# 2                    Standard                     Not Applicable
# 3                    Standard                     Not Applicable
# 4                    Standard                     Not Applicable
# 5                    Standard                     Not Applicable
# 6                    Standard                     Not Applicable
# 7                    Standard     Level 1 - Multi-Agency Support
# 8           Life Licence (LL)                     Not Applicable
# 9                    Standard                     Not Applicable
#
#   NATIONALITY_DESCRIPTION  NOMS_ID      NOMS_REGION_DESCRIPTION  \
# 0           Not Specified  A3946ET  PS-Yorkshire and The Humber
# 1           Not Specified  A7995ER                PS-North West
# 2           Not Specified  A7841EV             PS-South Central
# 3         BULGARIA ( BG )  A5983EV                PS-North East
# 4           Not Specified  A6536EQ                    PS-London
# 5           Not Specified  A8322EM                    PS-London
# 6   UNITED KINGDOM ( UK )  A0329EW             PS-West Midlands
# 7   UNITED KINGDOM ( UK )  A5551ER                PS-South West
# 8   UNITED KINGDOM ( UK )  A2689AM             PS-South Central
# 9   UNITED KINGDOM ( UK )  A1019AC  PS-Yorkshire and The Humber
#
#    NUMBER_OF_RECALL_REASONS OFFENDER_OWNING_TEAM_DESCRIPTION  \
# 0                         2                      Recall Team
# 1                         2                      Recall Team
# 2                         2                      Recall Team
# 3                         1                      Recall Team
# 4                         2                      Recall Team
# 5                         1                      Recall Team
# 6                         2                      Recall Team
# 7                         2                      Recall Team
# 8                         1                       PEC Team 3
# 9                         2                      Recall Team
#
#   STATUS_DESCRIPTION PB_DECISION_AFTER_BREACH_ACTUAL  \
# 0       Recalled [*]             15/07/2022 10:00:00
# 1       Recalled [*]             15/09/2022 16:00:00
# 2       Recalled [*]             19/08/2022 12:10:00
# 3       Recalled [*]             30/08/2022 12:30:00
# 4       Recalled [*]             26/07/2022 16:00:00
# 5       Recalled [*]             26/08/2022 12:00:00
# 6       Recalled [*]             15/09/2022 12:00:00
# 7       Recalled [*]             25/08/2022 14:15:00
# 8       Recalled [*]             27/09/2022 18:37:00
# 9       Recalled [*]             04/07/2022 14:46:00
#
#         POLICE_FORCE_DESCRIPTION PRISON_NUMBER     PROBATION_AREA_DESCRIPTION  \
# 0         South Yorkshire Police        26528E                 PS - Sheffield
# 1          Cheshire Constabulary        12264E                     PS - Crewe
# 2         Hampshire Constabulary        58629E  PS - Hampshire North and East
# 3             Northumbria Police        54208E       PS - Newcastle Upon Tyne
# 4             Met Police Service        85231D                    PS - Harrow
# 5             Met Police Service       2689229                 PS - Southwark
# 6           West Midlands Police        64268E             PS - Wolverhampton
# 7  Devon & Cornwall Constabulary        06761E          PS - Devon and Torbay
# 8         Hampshire Constabulary        FT9584  PS - Hampshire North and East
# 9              Humberside Police        11511E                      PS - Hull
#
#                           RECALL_REASON_DESCRIPTIONS  \
# 0  Poor Behaviour - non-compliance, Failed to kee...
# 1  Failed to reside, Poor Behaviour - non-compliance
# 2  Failed to reside, Poor Behaviour - non-compliance
# 3                            Failed to keep in touch
# 4          Failed to reside, Failed to keep in touch
# 5                    Poor Behaviour - non-compliance
# 6  Poor Behaviour - non-compliance, Failed to kee...
# 7  Poor Behaviour - non-compliance, Poor Behaviou...
# 8                    Poor Behaviour - non-compliance
# 9  Failed to reside, Poor Behaviour - non-compliance
#
#                       RECALL_TYPE_DESCRIPTION RECOMMEND_TO_EO_CWORKER_NAME  \
# 0  14 Day Fixed Term Recall - Under 12 Months                Afua Frimpong
# 1            Standard Recall - Over 12 Months                Afua Frimpong
# 2  14 Day Fixed Term Recall - Under 12 Months                Louise Adeoba
# 3  14 Day Fixed Term Recall - Under 12 Months               Estelle Donnan
# 4   28 Day Fixed Term Recall - Over 12 Months              Samantha Wasley
# 5   28 Day Fixed Term Recall - Over 12 Months              Sulemana Yesufu
# 6           Standard Recall - Under 12 Months                 Zaphia Lewis
# 7            Standard Recall - Over 12 Months              Patricia Magyar
# 8                        Indeterminate Recall              Mareikha Wright
# 9           Standard Recall - Under 12 Months              Samantha Wasley
#
#   REPORT_RECD_BY_UNIT_ACTUAL REPORT_RECD_BY_UNIT_TARGET  RESCIND_FLAG  \
# 0        15/07/2022 16:02:00        16/07/2022 10:00:00         False
# 1        16/09/2022 14:59:00        16/09/2022 16:00:00         False
# 2        19/08/2022 12:29:00        20/08/2022 12:10:00         False
# 3        30/08/2022 14:45:00        31/08/2022 12:30:00         False
# 4        27/07/2022 12:59:00        27/07/2022 16:00:00         False
# 5        26/08/2022 16:47:00        27/08/2022 12:00:00         False
# 6        16/09/2022 11:53:00        16/09/2022 12:00:00         False
# 7        25/08/2022 16:07:00        26/08/2022 14:15:00         False
# 8        27/09/2022 18:37:00        28/09/2022 18:37:00         False
# 9        04/07/2022 17:04:00        05/07/2022 14:46:00         False
#
#   REVOCATION_ISSUED_BY_NAME             RTC_DATE           RTC_TARGET  \
# 0          oooBrenda Campos  00/01/1900 00:00:00  19/07/2022 17:44:00
# 1            Simon O'Rourke  00/01/1900 00:00:00  20/09/2022 16:17:00
# 2             Claire Owens   00/01/1900 00:00:00  23/08/2022 16:52:00
# 3              Simon Dickie  00/01/1900 00:00:00  04/09/2022 10:02:00
# 4              Simon Dickie  00/01/1900 00:00:00  31/07/2022 15:16:00
# 5            Mobeen Hussain  22/09/2022 14:39:00  30/08/2022 17:48:00
# 6            Mobeen Hussain  12/12/2022 15:26:00  20/09/2022 14:01:00
# 7           Sophia Eyiangho  01/09/2022 10:49:00  30/08/2022 11:33:00
# 8              Kiran Bansal  01/10/2022 13:55:00  29/09/2022 19:49:00
# 9            Mobeen Hussain  06/07/2022 14:44:00  09/07/2022 10:41:00
#
#     TARIFF_EXPIRY_DATE  UAL_FLAG
# 0  00/01/1900 00:00:00      True
# 1  00/01/1900 00:00:00      True
# 2  00/01/1900 00:00:00      True
# 3  00/01/1900 00:00:00      True
# 4  00/01/1900 00:00:00      True
# 5  00/01/1900 00:00:00     False
# 6  00/01/1900 00:00:00     False
# 7  00/01/1900 00:00:00     False
# 8  28/09/2011 00:00:00     False
# 9  00/01/1900 00:00:00     False

# %%
# recalls.info()

# %%
# display(recalls.head(), extras.head())

# %%
# Remove some bizzare empty rows

recalls = recalls.loc[(recalls.LICENCE_REVOKE_DATE.notna()) & 
                      (recalls.FAMILY_NAME.notna())]
recalls.shape
# Out:
# (6210, 34)

# %%
# Copy original datetimes in new variables

recalls["LICENCE_REVOKE_TIME"] = recalls.LICENCE_REVOKE_DATE
recalls["RTC_TIME"] = recalls.RTC_DATE

extras["LICENCE_REVOKE_TIME"] = extras["LICENCE_REVOKE_DATE"]
extras["RTC_TIME"] = extras["RTC_DATE"]

# %%
# Convert to dates only (no time part)

recalls = dateConvert(recalls, "LICENCE_REVOKE_DATE")
recalls = dateConvert(recalls, "RTC_DATE")
recalls = dateConvert(recalls, "DOB")

extras = dateConvert(extras, "TARIFF_EXPIRY_DATE")
extras = dateConvert(extras, "DOS")
extras = dateConvert(extras, "DOB")
extras = dateConvert(extras, "LICENCE_REVOKE_DATE")

# %%
# Convert to date with timess only 

recalls = dateTimeConvert(recalls, "REPORT_RECD_BY_UNIT_ACTUAL")
recalls = dateTimeConvert(recalls, "REPORT_RECD_BY_UNIT_TARGET")
recalls = dateTimeConvert(recalls, "LICENCE_REVOKE_TIME")
recalls = dateTimeConvert(recalls, "ISSUE_REVOCATION_TARGET")
recalls = dateTimeConvert(recalls, "RTC_TIME")
recalls = dateTimeConvert(recalls, "RTC_TARGET")
recalls = dateTimeConvert(recalls, "PB_DECISION_AFTER_BREACH_ACTUAL")

# %%
# Tests
print(recalls[["LICENCE_REVOKE_TIME","LICENCE_REVOKE_DATE", "RTC_TIME","RTC_DATE"]].head())
print(recalls[["LICENCE_REVOKE_TIME","LICENCE_REVOKE_DATE", "RTC_TIME","RTC_DATE"]].dtypes)
print(extras[["DOS","TARIFF_EXPIRY_DATE"]].head())
# Out:
#   LICENCE_REVOKE_TIME LICENCE_REVOKE_DATE            RTC_TIME   RTC_DATE
# 0 2022-07-01 08:40:00          2022-07-01 2022-08-13 13:58:00 2022-08-13
# 1 2022-07-01 08:55:00          2022-07-01 2022-07-20 18:15:00 2022-07-20
# 2 2022-07-01 09:00:00          2022-07-01 2022-07-04 16:40:00 2022-07-04
# 3 2022-07-01 09:20:00          2022-07-01 2022-07-04 15:56:00 2022-07-04
# 4 2022-07-01 09:35:00          2022-07-01 2022-08-04 18:49:00 2022-08-04
# LICENCE_REVOKE_TIME    datetime64[ns]
# LICENCE_REVOKE_DATE    datetime64[ns]
# RTC_TIME               datetime64[ns]
# RTC_DATE               datetime64[ns]
# dtype: object
#          DOS TARIFF_EXPIRY_DATE
# 0 2022-02-02                NaT
# 1 2022-01-13                NaT
# 2 2022-06-27                NaT
# 3 2022-06-04                NaT
# 4 2021-07-19                NaT

# %% [markdown]
# ## Remove duplicates - don't execute code in this section if `rec2` below is empty

# %%
# Remove duplicate recalls from recalls data

rec2 = recalls.copy()
rec2['dups'] = rec2.groupby(['FILE_REFERENCE','LICENCE_REVOKE_DATE'])['LICENCE_REVOKE_DATE'].transform('count')
rec2 = rec2[rec2['dups'] > 1]

rec2.shape
# Out:
# (0, 37)

# %%
# Don't execute this if rec2 is empty

rec2['numb1'] = rec2.apply(lambda x: x.str.lower().str.contains("Not Applicable".lower()).sum(), axis=1)
rec2['numb2'] = rec2.apply(lambda x: x.str.lower().str.contains("Not specified".lower()).sum(), axis=1)
rec2['numb3'] = rec2.apply(lambda x: pd.isna(x).sum(), axis=1)
rec2['numb'] = rec2['numb1'] + rec2['numb2'] + rec2['numb3']

rec2.sort_values(['FILE_REFERENCE','numb'], inplace=True)
rec2 = rec2.drop_duplicates(subset=['FILE_REFERENCE'])  # keeps only the first entries with fewer missing data
rec2 = rec2.drop(columns=(['numb1','numb2','numb3','DUPS','numb']))
# rec2[['FILE_REFERENCE','numb']].head(20)

# %%
rec1 = recalls.copy()
rec1['dups'] = rec1.groupby(['FILE_REFERENCE','LICENCE_REVOKE_DATE'])['LICENCE_REVOKE_DATE'].transform('count')
rec1 = rec1[rec1['dups'] <= 1]

# %%
print(len(recalls),len(rec1))
# Out:
# 6210 6210

# %%
# Concatenate - don't do this if rec2 has zero entries

recalls1 = rec1.append(rec2).drop(['dups'],axis=1)
recalls1.info()

# %%
# CHECK AND CORRECT DUPLICATES BY FAMILY NAME, DOB AND LICENCE REVOKE DATE

check1 = recalls.copy()
check1['dups'] = check1.groupby(['FAMILY_NAME', 'DOB', 'LICENCE_REVOKE_DATE'])['LICENCE_REVOKE_DATE'].transform('count')
check1 = check1[check1['dups'] > 1]
check1.shape
# Out:
# (0, 37)

# %%
# Remove duplicate recalls from Extras data

rec2 = extras.copy()
rec2['dups'] = rec2.groupby(['FILE_REFERENCE','LICENCE_REVOKE_DATE'])['LICENCE_REVOKE_DATE'].transform('count')
rec2 = rec2[rec2['dups'] > 1]

rec2.shape
# Out:
# (0, 44)

# %%
# Don't execute this if rec2 is empty

rec2['numb1'] = rec2.apply(lambda x: x.str.lower().str.contains("Not Applicable".lower()).sum(), axis=1)
rec2['numb2'] = rec2.apply(lambda x: x.str.lower().str.contains("Not specified".lower()).sum(), axis=1)
rec2['numb3'] = rec2.apply(lambda x: pd.isna(x).sum(), axis=1)
rec2['numb'] = rec2['numb1'] + rec2['numb2'] + rec2['numb3']

rec2.sort_values(['FILE_REFERENCE','numb'], inplace=True)
rec2 = rec2.drop_duplicates(subset=['FILE_REFERENCE'])  # keeps only the first entries with fewer missing data
rec2 = rec2.drop(columns=(['numb1','numb2','numb3','DUPS','numb']))

rec2[['FILE_REFERENCE','numb']].head(20)

# %%
rec1 = extras.copy()
rec1['dups'] = rec1.groupby(['FILE_REFERENCE','LICENCE_REVOKE_DATE'])['LICENCE_REVOKE_DATE'].transform('count')
rec1 = rec1[rec1['dups'] <= 1]

# %%
print(len(extras),len(rec1))
# Out:
# 6210 6210

# %%
# Concatenate - don't do this if rec2 has zero entries

extras = rec1.append(rec2).drop(['DUPS'],axis=1)
extras.info()

# %%
# CHECK AND CORRECT DUPLICATES BY FAMILY NAME, DOB AND LICENCE REVOKE DATE

check1 = extras.copy()
check1['dups'] = check1.groupby(['FAMILY_NAME', 'DOB', 'LICENCE_REVOKE_DATE'])['LICENCE_REVOKE_DATE'].transform('count')
check1 = check1[check1['dups'] > 1]
check1.shape
# Out:
# (0, 44)

# %%
# delete rec1 and rec2 if they are not empty
del rec1
del rec2

# %%
# Names with digits - suprised python doesn't have anydigits() functions

def any_digits(x):
    return any(chr.isdigit() for chr in x)

# %%
extras[extras.FAMILY_NAME.apply(any_digits) |extras.FIRST_NAMES.apply(any_digits)]
# Out:
# Empty DataFrame
# Columns: [ALT_FILE_REFERENCE, CRO_PNC, CUSTODY_TYPE_DESCRIPTION, CUSTODY_TYPE_AT_TIME_OF_RECALL_DESCRIPTION, DOB, DOS, DETERMINATE_FLAG, ETHNICITY_DESCRIPTION, EWS_NUMBER, FAMILY_NAME, FILE_REFERENCE, FIRST_NAMES, GENDER, INDEX_OFFENCE_DESCRIPTION, ISSUE_REVOCATION_TARGET, LICENCE_END, LICENCE_REVOKE_DATE, LICENCE_START, TYPE_OF_LICENCE_DESCRIPTION, MAPPA_LEVEL_DESCRIPTION, NATIONALITY_DESCRIPTION, NOMS_ID, NOMS_REGION_DESCRIPTION, NUMBER_OF_RECALL_REASONS, OFFENDER_OWNING_TEAM_DESCRIPTION, STATUS_DESCRIPTION, PB_DECISION_AFTER_BREACH_ACTUAL, POLICE_FORCE_DESCRIPTION, PRISON_NUMBER, PROBATION_AREA_DESCRIPTION, RECALL_REASON_DESCRIPTIONS, RECALL_TYPE_DESCRIPTION, RECOMMEND_TO_EO_CWORKER_NAME, REPORT_RECD_BY_UNIT_ACTUAL, REPORT_RECD_BY_UNIT_TARGET, RESCIND_FLAG, REVOCATION_ISSUED_BY_NAME, RTC_DATE, RTC_TARGET, TARIFF_EXPIRY_DATE, UAL_FLAG, LICENCE_REVOKE_TIME, RTC_TIME]
# Index: []

# %%
recalls[recalls.FAMILY_NAME.apply(any_digits) | recalls.FIRST_NAMES.apply(any_digits)]
# Out:
# Empty DataFrame
# Columns: [ALT_FILE_REFERENCE, CRO_PNC, CUSTODY_TYPE_DESCRIPTION, CUSTODY_TYPE_AT_TIME_OF_RECALL_DESCRIPTION, DOB, DETERMINATE_FLAG, ETHNICITY_DESCRIPTION, EWS_NUMBER, FAMILY_NAME, FILE_REFERENCE, FIRST_NAMES, GENDER, INDEX_OFFENCE_DESCRIPTION, ISSUE_REVOCATION_TARGET, LICENCE_REVOKE_DATE, TYPE_OF_LICENCE_DESCRIPTION, MAPPA_LEVEL_DESCRIPTION, NATIONALITY_DESCRIPTION, NOMS_ID, NOMS_REGION_DESCRIPTION, STATUS_DESCRIPTION, PB_DECISION_AFTER_BREACH_ACTUAL, POLICE_FORCE_DESCRIPTION, PRISON_NUMBER, PROBATION_AREA_DESCRIPTION, RECALL_TYPE_DESCRIPTION, REPORT_RECD_BY_UNIT_ACTUAL, REPORT_RECD_BY_UNIT_TARGET, RESCIND_FLAG, RTC_DATE, RTC_TARGET, UAL_FLAG, OFFENDER_OWNING_TEAM_DESCRIPTION, RTC_NOTIF_METHOD_DESCRIPTION, LICENCE_REVOKE_TIME, RTC_TIME]
# Index: []

# %%
# Check for test cases*

extras[extras.FAMILY_NAME.str.contains("Test",case=False,regex=False) | \
       extras.FIRST_NAMES.str.contains("Test",case=False,regex=False)]
# Out:
# Empty DataFrame
# Columns: [ALT_FILE_REFERENCE, CRO_PNC, CUSTODY_TYPE_DESCRIPTION, CUSTODY_TYPE_AT_TIME_OF_RECALL_DESCRIPTION, DOB, DOS, DETERMINATE_FLAG, ETHNICITY_DESCRIPTION, EWS_NUMBER, FAMILY_NAME, FILE_REFERENCE, FIRST_NAMES, GENDER, INDEX_OFFENCE_DESCRIPTION, ISSUE_REVOCATION_TARGET, LICENCE_END, LICENCE_REVOKE_DATE, LICENCE_START, TYPE_OF_LICENCE_DESCRIPTION, MAPPA_LEVEL_DESCRIPTION, NATIONALITY_DESCRIPTION, NOMS_ID, NOMS_REGION_DESCRIPTION, NUMBER_OF_RECALL_REASONS, OFFENDER_OWNING_TEAM_DESCRIPTION, STATUS_DESCRIPTION, PB_DECISION_AFTER_BREACH_ACTUAL, POLICE_FORCE_DESCRIPTION, PRISON_NUMBER, PROBATION_AREA_DESCRIPTION, RECALL_REASON_DESCRIPTIONS, RECALL_TYPE_DESCRIPTION, RECOMMEND_TO_EO_CWORKER_NAME, REPORT_RECD_BY_UNIT_ACTUAL, REPORT_RECD_BY_UNIT_TARGET, RESCIND_FLAG, REVOCATION_ISSUED_BY_NAME, RTC_DATE, RTC_TARGET, TARIFF_EXPIRY_DATE, UAL_FLAG, LICENCE_REVOKE_TIME, RTC_TIME]
# Index: []

# %%
# Check for test cases*

recalls[recalls.FAMILY_NAME.str.contains("Test",case=False,regex=False) | \
        recalls.FIRST_NAMES.str.contains("Test",case=False,regex=False)]
# Out:
# Empty DataFrame
# Columns: [ALT_FILE_REFERENCE, CRO_PNC, CUSTODY_TYPE_DESCRIPTION, CUSTODY_TYPE_AT_TIME_OF_RECALL_DESCRIPTION, DOB, DETERMINATE_FLAG, ETHNICITY_DESCRIPTION, EWS_NUMBER, FAMILY_NAME, FILE_REFERENCE, FIRST_NAMES, GENDER, INDEX_OFFENCE_DESCRIPTION, ISSUE_REVOCATION_TARGET, LICENCE_REVOKE_DATE, TYPE_OF_LICENCE_DESCRIPTION, MAPPA_LEVEL_DESCRIPTION, NATIONALITY_DESCRIPTION, NOMS_ID, NOMS_REGION_DESCRIPTION, STATUS_DESCRIPTION, PB_DECISION_AFTER_BREACH_ACTUAL, POLICE_FORCE_DESCRIPTION, PRISON_NUMBER, PROBATION_AREA_DESCRIPTION, RECALL_TYPE_DESCRIPTION, REPORT_RECD_BY_UNIT_ACTUAL, REPORT_RECD_BY_UNIT_TARGET, RESCIND_FLAG, RTC_DATE, RTC_TARGET, UAL_FLAG, OFFENDER_OWNING_TEAM_DESCRIPTION, RTC_NOTIF_METHOD_DESCRIPTION, LICENCE_REVOKE_TIME, RTC_TIME]
# Index: []

# %%
# 5 Look for excess matches and non-Matches and make corrections

recalls_pub = duckdb.sql("\
    SELECT a.*, b.DOS, b.NUMBER_OF_RECALL_REASONS, \
        b.RECALL_REASON_DESCRIPTIONS,b.TARIFF_EXPIRY_DATE,b.FAMILY_NAME AS EXTRAS_FAMILY_NAME, \
        b.FIRST_NAMES AS EXTRAS_FIRST_NAME,b.DOB AS EXTRAS_DOB,b.FILE_REFERENCE AS FR,\
        b.PRISON_NUMBER AS PN\
    FROM recalls AS a LEFT JOIN extras AS b \
    ON  \
        (a.PRISON_NUMBER = b.PRISON_NUMBER  OR\
         a.FILE_REFERENCE = b.FILE_REFERENCE OR\
         (a.FAMILY_NAME = b.FAMILY_NAME AND a.DOB = b.DOB)\
        ) AND \
        a.LICENCE_REVOKE_DATE = b.LICENCE_REVOKE_DATE").df()

recalls_pub.shape
# Out:
# (6210, 45)

# %%
# Excess matches
retain_vars =['FILE_REFERENCE','PRISON_NUMBER', 'FAMILY_NAME', 'FIRST_NAMES','DOB',
              'LICENCE_REVOKE_DATE', 'EXTRAS_FAMILY_NAME', 'EXTRAS_FIRST_NAME','EXTRAS_DOB',
              'RTC_DATE', 'RECALL_TYPE_DESCRIPTION', 'FR','PN']

check1 = recalls_pub.copy()
check1['dups'] = recalls_pub.groupby(['FILE_REFERENCE','LICENCE_REVOKE_DATE'])['LICENCE_REVOKE_DATE'].transform('count')
check1 = check1[check1['dups'] > 1][retain_vars]

check1.shape
# Out:
# (0, 13)

# %%
# Check Non-Matches and resolve if check1 has entries

first_cols = ['FILE_REFERENCE', 'PRISON_NUMBER', 'FAMILY_NAME', 'LICENCE_REVOKE_DATE', 'RTC_DATE', 'RECALL_TYPE_DESCRIPTION']
last_cols = [col for col in recalls_pub.columns if col not in first_cols]

# chdf = df[first_cols+last_cols]
check1 = recalls_pub.loc[recalls_pub.RECALL_REASON_DESCRIPTIONS.isna()][first_cols+last_cols]
display(check1)
# Out:
#      FILE_REFERENCE PRISON_NUMBER FAMILY_NAME LICENCE_REVOKE_DATE RTC_DATE  \
# 6143     PPU_385937        55196D      Cooper          2022-09-07      NaT
#
#                RECALL_TYPE_DESCRIPTION ALT_FILE_REFERENCE     CRO_PNC  \
# 6143  Standard Recall - Over 12 Months                NaN  176196/05Z
#
#      CUSTODY_TYPE_DESCRIPTION CUSTODY_TYPE_AT_TIME_OF_RECALL_DESCRIPTION  \
# 6143              Determinate                                Determinate
#
#             DOB  DETERMINATE_FLAG ETHNICITY_DESCRIPTION EWS_NUMBER  \
# 6143 1991-02-09              True       White - British        NaN
#
#      FIRST_NAMES GENDER INDEX_OFFENCE_DESCRIPTION ISSUE_REVOCATION_TARGET  \
# 6143         Jon      M                    AFFRAY     2022-09-08 10:15:00
#
#      TYPE_OF_LICENCE_DESCRIPTION         MAPPA_LEVEL_DESCRIPTION  \
# 6143                    Standard  Level 1 - Multi-Agency Support
#
#      NATIONALITY_DESCRIPTION  NOMS_ID NOMS_REGION_DESCRIPTION  \
# 6143   UNITED KINGDOM ( UK )  A0319CC      PS-East of England
#
#      STATUS_DESCRIPTION PB_DECISION_AFTER_BREACH_ACTUAL  \
# 6143       Recalled [*]             2022-09-07 08:30:00
#
#          POLICE_FORCE_DESCRIPTION            PROBATION_AREA_DESCRIPTION  \
# 6143  Cambridgeshire Constabulary  PS - Cambridgeshire and Peterborough
#
#      REPORT_RECD_BY_UNIT_ACTUAL REPORT_RECD_BY_UNIT_TARGET  RESCIND_FLAG  \
# 6143        2022-09-07 10:15:00        2022-09-08 08:30:00         False
#
#               RTC_TARGET  UAL_FLAG OFFENDER_OWNING_TEAM_DESCRIPTION  \
# 6143 2022-09-11 10:46:00     False                      Recall Team
#
#      RTC_NOTIF_METHOD_DESCRIPTION LICENCE_REVOKE_TIME RTC_TIME DOS  \
# 6143                Not Specified 2022-09-07 10:46:00      NaT NaT
#
#       NUMBER_OF_RECALL_REASONS RECALL_REASON_DESCRIPTIONS TARIFF_EXPIRY_DATE  \
# 6143                       NaN                        NaN                NaT
#
#      EXTRAS_FAMILY_NAME EXTRAS_FIRST_NAME EXTRAS_DOB   FR   PN
# 6143                NaN               NaN        NaT  NaN  NaN

# %%
# Drop unmatched after checking with Jackie
recalls = recalls[(recalls.FILE_REFERENCE != "PPU_385937") |\
                    (recalls.PRISON_NUMBER != "55196D")]

recalls.shape
# Out:
# (6209, 36)

# %%
recalls.dtypes
# Out:
# ALT_FILE_REFERENCE                                    object
# CRO_PNC                                               object
# CUSTODY_TYPE_DESCRIPTION                              object
# CUSTODY_TYPE_AT_TIME_OF_RECALL_DESCRIPTION            object
# DOB                                           datetime64[ns]
# DETERMINATE_FLAG                                        bool
# ETHNICITY_DESCRIPTION                                 object
# EWS_NUMBER                                            object
# FAMILY_NAME                                           object
# FILE_REFERENCE                                        object
# FIRST_NAMES                                           object
# GENDER                                                object
# INDEX_OFFENCE_DESCRIPTION                             object
# ISSUE_REVOCATION_TARGET                       datetime64[ns]
# LICENCE_REVOKE_DATE                           datetime64[ns]
# TYPE_OF_LICENCE_DESCRIPTION                           object
# MAPPA_LEVEL_DESCRIPTION                               object
# NATIONALITY_DESCRIPTION                               object
# NOMS_ID                                               object
# NOMS_REGION_DESCRIPTION                               object
# STATUS_DESCRIPTION                                    object
# PB_DECISION_AFTER_BREACH_ACTUAL               datetime64[ns]
# POLICE_FORCE_DESCRIPTION                              object
# PRISON_NUMBER                                         object
# PROBATION_AREA_DESCRIPTION                            object
# RECALL_TYPE_DESCRIPTION                               object
# REPORT_RECD_BY_UNIT_ACTUAL                    datetime64[ns]
# REPORT_RECD_BY_UNIT_TARGET                    datetime64[ns]
# RESCIND_FLAG                                            bool
# RTC_DATE                                      datetime64[ns]
# RTC_TARGET                                    datetime64[ns]
# UAL_FLAG                                                bool
# OFFENDER_OWNING_TEAM_DESCRIPTION                      object
# RTC_NOTIF_METHOD_DESCRIPTION                          object
# LICENCE_REVOKE_TIME                           datetime64[ns]
# RTC_TIME                                      datetime64[ns]
# dtype: object

# %%
extras_bup = extras.copy()
recalls_bup = recalls.copy()

# %%
# if required reset defaults on number of rows and columns to display - any of the options below works

# pd.reset_option('max_columns')
# pd.reset_option('max_rows')
