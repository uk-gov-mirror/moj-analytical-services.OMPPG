# %%
# Libraries
import pandas as pd

# %%
# Max rows and columns - any of the options below works

# print(pd.get_option('display.max_columns'), pd.get_option('display.max_rows'))
print("Defaults: max_col: {}, max_rows: {}, col_width:{}, Number of decimal places: {}".\
      format(pd.get_option('max_columns'), 
             pd.get_option('max_rows'),
             pd.get_option('max_colwidth'),
             pd.get_option('precision')
            )
)
# Out:
# Defaults: max_col: 20, max_rows: 60, col_width:50, Number of decimal places: 6

# %%
# remove limits on number of rows and columns to display - any of the options below works

# pd.set_option('display.max_columns',None)
# pd.set_option('display.max_rows',None)

pd.set_option('max_columns',None)
pd.set_option('max_rows',None)
# pd.set_option('max_colwidth',None)

# %%
extras = pd.read_excel('s3://alpha-omppg/Recalls/PPUD/Extra Variables/PPUD_Recalls_2022Q3_Extra.xls')
recalls = pd.read_excel('s3://alpha-omppg/Recalls/PPUD/Audited/PPUD_Recalls_2022Q3.xls')

# %%
extras.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6210 entries, 0 to 6209
# Data columns (total 41 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   ALT_FILE_REFERENCE                          396 non-null    object
#  1   CRO_PNC                                     6207 non-null   object
#  2   CUSTODY_TYPE_DESCRIPTION                    6210 non-null   object
#  3   CUSTODY_TYPE_AT_TIME_OF_RECALL_DESCRIPTION  6210 non-null   object
#  4   DOB                                         6210 non-null   object
#  5   DOS                                         6210 non-null   object
#  6   DETERMINATE_FLAG                            6210 non-null   bool
#  7   ETHNICITY_DESCRIPTION                       6210 non-null   object
#  8   EWS_NUMBER                                  5124 non-null   object
#  9   FAMILY_NAME                                 6210 non-null   object
# ...

# %%
extras.head()
# Out:
#   ALT_FILE_REFERENCE    CRO_PNC CUSTODY_TYPE_DESCRIPTION  \
# 0                NaN  80641/22W              Determinate
# 1                NaN  87718/21G              Determinate
# 2                NaN  98777/22J              Determinate
# 3                NaN        NaN              Determinate
# 4                NaN        NaN              Determinate
#
#   CUSTODY_TYPE_AT_TIME_OF_RECALL_DESCRIPTION                  DOB  \
# 0                                Determinate  29/04/1998 00:00:00
# 1                                Determinate  08/01/1981 00:00:00
# 2                                Determinate  20/09/1972 00:00:00
# 3                                Determinate  07/10/1996 00:00:00
# 4                                Determinate  04/11/1999 00:00:00
#
#                    DOS  DETERMINATE_FLAG ETHNICITY_DESCRIPTION  \
# 0  02/02/2022 00:00:00              True         White - Other
# 1  13/01/2022 00:00:00              True               Chinese
# ...

# %%
recalls.head()
# Out:
#   ALT_FILE_REFERENCE     CRO_PNC CUSTODY_TYPE_DESCRIPTION  \
# 0                NaN   48908/93R              Determinate
# 1                NaN  133027/88T              Determinate
# 2                NaN  145792/21F              Determinate
# 3                NaN  105699/93W              Determinate
# 4                NaN   76927/92Q              Determinate
#
#   CUSTODY_TYPE_AT_TIME_OF_RECALL_DESCRIPTION                  DOB  \
# 0                                Determinate  10/07/1980 00:00:00
# 1                                Determinate  09/04/1974 00:00:00
# 2                                Determinate  25/05/1986 00:00:00
# 3                                Determinate  17/08/1975 00:00:00
# 4                                Determinate  14/03/1975 00:00:00
#
#    DETERMINATE_FLAG ETHNICITY_DESCRIPTION          EWS_NUMBER FAMILY_NAME  \
# 0              True       White - British  02RC/2089797B01072        Ward
# ...

# %%
recalls = recalls[recalls["LICENCE_REVOKE_DATE"].notna() & recalls["FAMILY_NAME"].notna()]
lyll''lll

# %%
"licence_revoke_date".upper()
# Out:
# 'LICENCE_REVOKE_DATE'

# %%
recalls["LICENCE_REVOKE_DATE"].notna() and recalls["FAMILY_NAME"].notna()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-2c2aa5dd27d7> in <module>
# ----> 1 recalls["LICENCE_REVOKE_DATE"].notna() and recalls["FAMILY_NAME"].notna()
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1440     @final
#    1441     def __nonzero__(self):
# -> 1442         raise ValueError(
#    1443             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1444             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
# if required reset defaults on number of rows and columns to display - any of the options below works

# pd.reset_option('max_columns')
# pd.reset_option('max_rows')
